# %% [markdown]
# # Computational Astrophysics 2021
# ---
# ## Eduard Larrañaga
#
# Observatorio Astronómico Nacional\
# Facultad de Ciencias\
# Universidad Nacional de Colombia
#
# ---

# %% [markdown]
# ## Exercises 05.
#
# **Name:**
#
# ---

# %% [markdown]
# ### Real Supernova Lightcurves
#
# From the webpage of the **A**merican **A**ssociation of **V**ariable **S**tars **O**bservers (**AAVSO**),
# https://www.aavso.org , you must download the data for the lightcurves of the supernovas
#
# SN 2017eaw
# SN 2015F
# SN 2014J

# %% [markdown]
# 1. Plot the data to create the lightcurves for the three supernovas.
#
# 2. Adjust an adequate template from the wabepage of Peter Nugent,
#
# https://c3.lbl.gov/nugent/nugent_templates.html
#
# to each of the lightcurves.
